# %%
import os
import cv2
import numpy as np
from PIL import Image
from keras.applications.vgg16 import VGG16
from keras.utils import to_categorical
import keras
from keras import layers
from keras.layers import *
from keras.models import Model, Sequential
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import h5py
from matplotlib import pyplot as plt
from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
ck_data = h5py.File('./CK_data.h5', 'r', driver='core')

# %%
X_data = np.expand_dims(np.asarray(ck_data['data_pixel']), axis=-1)

# %%
Y_data = np.asarray(ck_data['data_label'])

# %%
Y_data = to_categorical(Y_data)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size=0.2)

# %%
num_train = X_train.shape[0]

# %%
num_val = X_test.shape[0]

# %%
print('Training: ',X_train.shape)
# Out:
# Training:  (784, 48, 48, 1)

# %%
print('Validation: ',X_test.shape)
# Out:
# Validation:  (197, 48, 48, 1)

# %%
from keras.layers import Convolution2D, Activation, BatchNormalization, MaxPooling2D, Dropout, Dense, Flatten, AveragePooling2D

# %%
from keras.models import Sequential

# %%
def get_nn_model():
    model = Sequential()
    model.add(Flatten(input_shape=(48,48,1)))
    model.add(Dense(512))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))

    model.add(Dense(256))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))

    model.add(Dense(7))
    model.add(Activation('softmax'))
    return model

# %%
def get_cnn_model():
    model = Sequential()

    model.add(Convolution2D(64, (3, 1), padding='same', input_shape=(48,48,1)))
    model.add(Convolution2D(64, (1, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
    model.add(Dropout(0.25))

    model.add(Convolution2D(128, (3, 1), padding='same'))
    model.add(Convolution2D(128, (1, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
    model.add(Dropout(0.25))

    model.add(Convolution2D(256, (3, 1), padding='same'))
    model.add(Convolution2D(256, (1, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
    model.add(Dropout(0.25))

    model.add(Convolution2D(512, (3, 1), padding='same'))
    model.add(Convolution2D(512, (1, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=None, padding='same'))
    model.add(Dropout(0.25))

    model.add(Flatten())

    model.add(Dense(512))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))

    model.add(Dense(256))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.25))

    model.add(Dense(7))
    model.add(Activation('softmax'))
    return model

# %%
cnn_model = get_cnn_model()
# Out:
# WARNING:tensorflow:From /usr/local/miniconda3/envs/dl/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/miniconda3/envs/dl/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
nn_model = get_nn_model()

# %%
cnn_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        12352
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 128)       24704
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 128)       49280
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 256)       98560
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 12, 12, 256)       196864
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 12, 12, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 512)         393728
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 6, 6, 512)         786944
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_4 (Activation)    (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               2359808
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 1799
# _________________________________________________________________
# activation_7 (Activation)    (None, 7)                 0
# =================================================================
# Total params: 4,062,535
# Trainable params: 4,059,079
# Non-trainable params: 3,456
# _________________________________________________________________

# %%
nn_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_9 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 1799
# _________________________________________________________________
# activation_10 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 1,316,359
# Trainable params: 1,314,823
# Non-trainable params: 1,536
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
from keras import backend as K

# %%
def fbeta(y_true, y_pred, threshold_shift=0):
    beta = 1

    # just in case of hipster activation at the final layer
    y_pred = K.clip(y_pred, 0, 1)

    # shifting the prediction threshold from .5 if needed
    y_pred_bin = K.round(y_pred + threshold_shift)

    tp = K.sum(K.round(y_true * y_pred_bin), axis=1) + K.epsilon()
    fp = K.sum(K.round(K.clip(y_pred_bin - y_true, 0, 1)), axis=1)
    fn = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=1)

    precision = tp / (tp + fp)
    recall = tp / (tp + fn)

    beta_squared = beta ** 2
    return K.mean((beta_squared + 1) * (precision * recall) / (beta_squared * precision + recall + K.epsilon()))

# %%
def train_cnn_model(model):
    filepath='../opt/ck-cnn/Model.{epoch:02d}-{val_acc:.4f}.hdf5'
    checkpointer = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, mode='auto')
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=0, mode='auto', cooldown=0, min_lr=0)
    early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto')
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.0,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.0,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,   # randomly flip images
        )


    datagen.fit(X_train)
    datagen.fit(X_test)    
    batch_size = 32

    num_epochs = 25
    model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=[fbeta, 'acc'])
    train_flow = datagen.flow(X_train, Y_train, batch_size=batch_size)
    test_flow = datagen.flow(X_test, Y_test)
    history = model.fit_generator(train_flow,
                    steps_per_epoch=len(X_train) / batch_size,
                    epochs=num_epochs, 
                    verbose=1, 
                    validation_data=test_flow, 
                    validation_steps=len(X_test) / batch_size,
                    callbacks=[checkpointer, reduce_lr, checkpointer])
    return history, model

# %%
def train_nn_model(model):
    filepath='../opt/ck-nn/Model.{epoch:02d}-{val_acc:.4f}.hdf5'
    checkpointer = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, mode='auto')
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=0, mode='auto', cooldown=0, min_lr=0)
    early_stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto')
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.0,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.0,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,   # randomly flip images
        )


    datagen.fit(X_train)
    datagen.fit(X_test)    
    batch_size = 32

    num_epochs = 25
    model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=[fbeta, 'acc'])
    train_flow = datagen.flow(X_train, Y_train, batch_size=batch_size)
    test_flow = datagen.flow(X_test, Y_test)
    history = model.fit_generator(train_flow,
                    steps_per_epoch=len(X_train) / batch_size,
                    epochs=num_epochs, 
                    verbose=1, 
                    validation_data=test_flow, 
                    validation_steps=len(X_test) / batch_size,
                    callbacks=[checkpointer, reduce_lr, checkpointer])
    return history, model

# %%
history, cnn_model = train_cnn_model(cnn_model)
# Out:
# WARNING:tensorflow:From /usr/local/miniconda3/envs/dl/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/25
# 25/24 [==============================] - 3s 120ms/step - loss: 1.8466 - fbeta: 0.2011 - acc: 0.3811 - val_loss: 4.2595 - val_fbeta: 0.2386 - val_acc: 0.2437
#
# Epoch 00001: saving model to ../opt/ck-cnn/Model.01-0.2437.hdf5
#
# Epoch 00001: saving model to ../opt/ck-cnn/Model.01-0.2437.hdf5
# Epoch 2/25
# 25/24 [==============================] - 0s 17ms/step - loss: 1.0635 - fbeta: 0.4998 - acc: 0.6149 - val_loss: 1.0127 - val_fbeta: 0.5787 - val_acc: 0.6650
#
# Epoch 00002: saving model to ../opt/ck-cnn/Model.02-0.6650.hdf5
#
# Epoch 00002: saving model to ../opt/ck-cnn/Model.02-0.6650.hdf5
# Epoch 3/25
# 25/24 [==============================] - 0s 18ms/step - loss: 0.7239 - fbeta: 0.6424 - acc: 0.7574 - val_loss: 0.6192 - val_fbeta: 0.7056 - val_acc: 0.7614
#
# Epoch 00003: saving model to ../opt/ck-cnn/Model.03-0.7614.hdf5
#
# Epoch 00003: saving model to ../opt/ck-cnn/Model.03-0.7614.hdf5
# Epoch 4/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.5107 - fbeta: 0.7500 - acc: 0.8250 - val_loss: 1.0503 - val_fbeta: 0.6244 - val_acc: 0.6599
#
# Epoch 00004: saving model to ../opt/ck-cnn/Model.04-0.6599.hdf5
#
# Epoch 00004: saving model to ../opt/ck-cnn/Model.04-0.6599.hdf5
# Epoch 5/25
# 25/24 [==============================] - 0s 18ms/step - loss: 0.4208 - fbeta: 0.8150 - acc: 0.8625 - val_loss: 0.3514 - val_fbeta: 0.8528 - val_acc: 0.8782
#
# Epoch 00005: saving model to ../opt/ck-cnn/Model.05-0.8782.hdf5
#
# Epoch 00005: saving model to ../opt/ck-cnn/Model.05-0.8782.hdf5
# Epoch 6/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.3164 - fbeta: 0.8612 - acc: 0.8950 - val_loss: 0.2326 - val_fbeta: 0.8934 - val_acc: 0.9289
#
# Epoch 00006: saving model to ../opt/ck-cnn/Model.06-0.9289.hdf5
#
# Epoch 00006: saving model to ../opt/ck-cnn/Model.06-0.9289.hdf5
# Epoch 7/25
# 25/24 [==============================] - 0s 18ms/step - loss: 0.2466 - fbeta: 0.8900 - acc: 0.9137 - val_loss: 0.7380 - val_fbeta: 0.7614 - val_acc: 0.7665
#
# Epoch 00007: saving model to ../opt/ck-cnn/Model.07-0.7665.hdf5
#
# Epoch 00007: saving model to ../opt/ck-cnn/Model.07-0.7665.hdf5
# Epoch 8/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.2049 - fbeta: 0.9050 - acc: 0.9337 - val_loss: 0.2153 - val_fbeta: 0.8934 - val_acc: 0.9239
#
# Epoch 00008: saving model to ../opt/ck-cnn/Model.08-0.9239.hdf5
#
# Epoch 00008: saving model to ../opt/ck-cnn/Model.08-0.9239.hdf5
# Epoch 9/25
# 25/24 [==============================] - 0s 18ms/step - loss: 0.2251 - fbeta: 0.9175 - acc: 0.9250 - val_loss: 0.2845 - val_fbeta: 0.8832 - val_acc: 0.9036
#
# Epoch 00009: saving model to ../opt/ck-cnn/Model.09-0.9036.hdf5
#
# Epoch 00009: saving model to ../opt/ck-cnn/Model.09-0.9036.hdf5
# Epoch 10/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.1805 - fbeta: 0.9349 - acc: 0.9412 - val_loss: 0.1872 - val_fbeta: 0.9340 - val_acc: 0.9543
#
# Epoch 00010: saving model to ../opt/ck-cnn/Model.10-0.9543.hdf5
#
# Epoch 00010: saving model to ../opt/ck-cnn/Model.10-0.9543.hdf5
# Epoch 11/25
# 25/24 [==============================] - 0s 18ms/step - loss: 0.1483 - fbeta: 0.9401 - acc: 0.9501 - val_loss: 0.1572 - val_fbeta: 0.9340 - val_acc: 0.9492
#
# Epoch 00011: saving model to ../opt/ck-cnn/Model.11-0.9492.hdf5
#
# Epoch 00011: saving model to ../opt/ck-cnn/Model.11-0.9492.hdf5
# Epoch 12/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.1594 - fbeta: 0.9375 - acc: 0.9451 - val_loss: 0.1893 - val_fbeta: 0.9086 - val_acc: 0.9137
#
# Epoch 00012: saving model to ../opt/ck-cnn/Model.12-0.9137.hdf5
#
# Epoch 00012: saving model to ../opt/ck-cnn/Model.12-0.9137.hdf5
# Epoch 13/25
# 25/24 [==============================] - 0s 18ms/step - loss: 0.1476 - fbeta: 0.9375 - acc: 0.9462 - val_loss: 0.3499 - val_fbeta: 0.8528 - val_acc: 0.8731
#
# Epoch 00013: saving model to ../opt/ck-cnn/Model.13-0.8731.hdf5
#
# Epoch 00013: saving model to ../opt/ck-cnn/Model.13-0.8731.hdf5
# Epoch 14/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.1215 - fbeta: 0.9488 - acc: 0.9551 - val_loss: 0.2276 - val_fbeta: 0.9188 - val_acc: 0.9188
#
# Epoch 00014: saving model to ../opt/ck-cnn/Model.14-0.9188.hdf5
#
# Epoch 00014: saving model to ../opt/ck-cnn/Model.14-0.9188.hdf5
# Epoch 15/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.1461 - fbeta: 0.9563 - acc: 0.9576 - val_loss: 0.1444 - val_fbeta: 0.9543 - val_acc: 0.9543
#
# Epoch 00015: saving model to ../opt/ck-cnn/Model.15-0.9543.hdf5
#
# Epoch 00015: saving model to ../opt/ck-cnn/Model.15-0.9543.hdf5
# Epoch 16/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.1381 - fbeta: 0.9413 - acc: 0.9463 - val_loss: 0.4299 - val_fbeta: 0.8731 - val_acc: 0.8782
#
# Epoch 00016: saving model to ../opt/ck-cnn/Model.16-0.8782.hdf5
#
# Epoch 00016: saving model to ../opt/ck-cnn/Model.16-0.8782.hdf5
# Epoch 17/25
# 25/24 [==============================] - 0s 18ms/step - loss: 0.1067 - fbeta: 0.9537 - acc: 0.9662 - val_loss: 0.2509 - val_fbeta: 0.8985 - val_acc: 0.9036
#
# Epoch 00017: saving model to ../opt/ck-cnn/Model.17-0.9036.hdf5
#
# Epoch 00017: saving model to ../opt/ck-cnn/Model.17-0.9036.hdf5
# Epoch 18/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.1135 - fbeta: 0.9513 - acc: 0.9588 - val_loss: 0.2324 - val_fbeta: 0.9036 - val_acc: 0.9137
#
# Epoch 00018: saving model to ../opt/ck-cnn/Model.18-0.9137.hdf5
#
# Epoch 00018: saving model to ../opt/ck-cnn/Model.18-0.9137.hdf5
# Epoch 19/25
# 25/24 [==============================] - 0s 19ms/step - loss: 0.0815 - fbeta: 0.9713 - acc: 0.9750 - val_loss: 0.6029 - val_fbeta: 0.8173 - val_acc: 0.8223
#
# Epoch 00019: saving model to ../opt/ck-cnn/Model.19-0.8223.hdf5
#
# Epoch 00019: saving model to ../opt/ck-cnn/Model.19-0.8223.hdf5
# Epoch 20/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.0792 - fbeta: 0.9700 - acc: 0.9762 - val_loss: 0.0706 - val_fbeta: 0.9695 - val_acc: 0.9797
#
# Epoch 00020: saving model to ../opt/ck-cnn/Model.20-0.9797.hdf5
#
# Epoch 00020: saving model to ../opt/ck-cnn/Model.20-0.9797.hdf5
# Epoch 21/25
# 25/24 [==============================] - 0s 18ms/step - loss: 0.0629 - fbeta: 0.9763 - acc: 0.9862 - val_loss: 0.0424 - val_fbeta: 0.9797 - val_acc: 0.9898
#
# Epoch 00021: saving model to ../opt/ck-cnn/Model.21-0.9898.hdf5
#
# Epoch 00021: saving model to ../opt/ck-cnn/Model.21-0.9898.hdf5
# Epoch 22/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.0610 - fbeta: 0.9776 - acc: 0.9826 - val_loss: 0.0645 - val_fbeta: 0.9645 - val_acc: 0.9797
#
# Epoch 00022: saving model to ../opt/ck-cnn/Model.22-0.9797.hdf5
#
# Epoch 00022: saving model to ../opt/ck-cnn/Model.22-0.9797.hdf5
# Epoch 23/25
# 25/24 [==============================] - 0s 18ms/step - loss: 0.0480 - fbeta: 0.9837 - acc: 0.9850 - val_loss: 0.1164 - val_fbeta: 0.9442 - val_acc: 0.9543
#
# Epoch 00023: saving model to ../opt/ck-cnn/Model.23-0.9543.hdf5
#
# Epoch 00023: saving model to ../opt/ck-cnn/Model.23-0.9543.hdf5
# Epoch 24/25
# 25/24 [==============================] - 0s 18ms/step - loss: 0.0332 - fbeta: 0.9925 - acc: 0.9937 - val_loss: 0.1387 - val_fbeta: 0.9442 - val_acc: 0.9442
#
# Epoch 00024: saving model to ../opt/ck-cnn/Model.24-0.9442.hdf5
#
# Epoch 00024: saving model to ../opt/ck-cnn/Model.24-0.9442.hdf5
# Epoch 25/25
# 25/24 [==============================] - 0s 17ms/step - loss: 0.0549 - fbeta: 0.9763 - acc: 0.9801 - val_loss: 0.0866 - val_fbeta: 0.9645 - val_acc: 0.9695
#
# Epoch 00025: saving model to ../opt/ck-cnn/Model.25-0.9695.hdf5
#
# Epoch 00025: saving model to ../opt/ck-cnn/Model.25-0.9695.hdf5

# %%
nn_history, nn_model = train_nn_model(nn_model)
# Out:
# Epoch 1/25
# 25/24 [==============================] - 1s 36ms/step - loss: 1.3183 - fbeta: 0.3812 - acc: 0.5462 - val_loss: 1.1994 - val_fbeta: 0.4721 - val_acc: 0.5228
#
# Epoch 00001: saving model to ../opt/ck-nn/Model.01-0.5228.hdf5
#
# Epoch 00001: saving model to ../opt/ck-nn/Model.01-0.5228.hdf5
# Epoch 2/25
# 25/24 [==============================] - 0s 7ms/step - loss: 0.6408 - fbeta: 0.6838 - acc: 0.7875 - val_loss: 0.9612 - val_fbeta: 0.6396 - val_acc: 0.6853
#
# Epoch 00002: saving model to ../opt/ck-nn/Model.02-0.6853.hdf5
#
# Epoch 00002: saving model to ../opt/ck-nn/Model.02-0.6853.hdf5
# Epoch 3/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.4875 - fbeta: 0.7512 - acc: 0.8237 - val_loss: 1.0262 - val_fbeta: 0.5533 - val_acc: 0.6142
#
# Epoch 00003: saving model to ../opt/ck-nn/Model.03-0.6142.hdf5
#
# Epoch 00003: saving model to ../opt/ck-nn/Model.03-0.6142.hdf5
# Epoch 4/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.4011 - fbeta: 0.8126 - acc: 0.8714 - val_loss: 1.1079 - val_fbeta: 0.6701 - val_acc: 0.7259
#
# Epoch 00004: saving model to ../opt/ck-nn/Model.04-0.7259.hdf5
#
# Epoch 00004: saving model to ../opt/ck-nn/Model.04-0.7259.hdf5
# Epoch 5/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.3549 - fbeta: 0.8351 - acc: 0.8788 - val_loss: 1.0529 - val_fbeta: 0.7766 - val_acc: 0.7970
#
# Epoch 00005: saving model to ../opt/ck-nn/Model.05-0.7970.hdf5
#
# Epoch 00005: saving model to ../opt/ck-nn/Model.05-0.7970.hdf5
# Epoch 6/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.2927 - fbeta: 0.8688 - acc: 0.9112 - val_loss: 1.3316 - val_fbeta: 0.6853 - val_acc: 0.7005
#
# Epoch 00006: saving model to ../opt/ck-nn/Model.06-0.7005.hdf5
#
# Epoch 00006: saving model to ../opt/ck-nn/Model.06-0.7005.hdf5
# Epoch 7/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.2208 - fbeta: 0.9250 - acc: 0.9426 - val_loss: 1.0007 - val_fbeta: 0.7766 - val_acc: 0.8020
#
# Epoch 00007: saving model to ../opt/ck-nn/Model.07-0.8020.hdf5
#
# Epoch 00007: saving model to ../opt/ck-nn/Model.07-0.8020.hdf5
# Epoch 8/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.2092 - fbeta: 0.9138 - acc: 0.9375 - val_loss: 0.9206 - val_fbeta: 0.7107 - val_acc: 0.7310
#
# Epoch 00008: saving model to ../opt/ck-nn/Model.08-0.7310.hdf5
#
# Epoch 00008: saving model to ../opt/ck-nn/Model.08-0.7310.hdf5
# Epoch 9/25
# 25/24 [==============================] - 0s 6ms/step - loss: 0.1771 - fbeta: 0.9312 - acc: 0.9450 - val_loss: 0.6728 - val_fbeta: 0.7970 - val_acc: 0.8020
#
# Epoch 00009: saving model to ../opt/ck-nn/Model.09-0.8020.hdf5
#
# Epoch 00009: saving model to ../opt/ck-nn/Model.09-0.8020.hdf5
# Epoch 10/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.1770 - fbeta: 0.9262 - acc: 0.9462 - val_loss: 1.1958 - val_fbeta: 0.6193 - val_acc: 0.6345
#
# Epoch 00010: saving model to ../opt/ck-nn/Model.10-0.6345.hdf5
#
# Epoch 00010: saving model to ../opt/ck-nn/Model.10-0.6345.hdf5
# Epoch 11/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.1404 - fbeta: 0.9475 - acc: 0.9650 - val_loss: 0.8877 - val_fbeta: 0.7411 - val_acc: 0.7665
#
# Epoch 00011: saving model to ../opt/ck-nn/Model.11-0.7665.hdf5
#
# Epoch 00011: saving model to ../opt/ck-nn/Model.11-0.7665.hdf5
# Epoch 12/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.1751 - fbeta: 0.9375 - acc: 0.9462 - val_loss: 0.6579 - val_fbeta: 0.8223 - val_acc: 0.8426
#
# Epoch 00012: saving model to ../opt/ck-nn/Model.12-0.8426.hdf5
#
# Epoch 00012: saving model to ../opt/ck-nn/Model.12-0.8426.hdf5
# Epoch 13/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.1067 - fbeta: 0.9575 - acc: 0.9688 - val_loss: 2.4857 - val_fbeta: 0.4010 - val_acc: 0.4264
#
# Epoch 00013: saving model to ../opt/ck-nn/Model.13-0.4264.hdf5
#
# Epoch 00013: saving model to ../opt/ck-nn/Model.13-0.4264.hdf5
# Epoch 14/25
# 25/24 [==============================] - 0s 6ms/step - loss: 0.1346 - fbeta: 0.9488 - acc: 0.9538 - val_loss: 1.4300 - val_fbeta: 0.5431 - val_acc: 0.5635
#
# Epoch 00014: saving model to ../opt/ck-nn/Model.14-0.5635.hdf5
#
# Epoch 00014: saving model to ../opt/ck-nn/Model.14-0.5635.hdf5
# Epoch 15/25
# 25/24 [==============================] - 0s 6ms/step - loss: 0.1307 - fbeta: 0.9488 - acc: 0.9663 - val_loss: 0.8216 - val_fbeta: 0.6954 - val_acc: 0.7208
#
# Epoch 00015: saving model to ../opt/ck-nn/Model.15-0.7208.hdf5
#
# Epoch 00015: saving model to ../opt/ck-nn/Model.15-0.7208.hdf5
# Epoch 16/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.1034 - fbeta: 0.9712 - acc: 0.9725 - val_loss: 0.4853 - val_fbeta: 0.8071 - val_acc: 0.8274
#
# Epoch 00016: saving model to ../opt/ck-nn/Model.16-0.8274.hdf5
#
# Epoch 00016: saving model to ../opt/ck-nn/Model.16-0.8274.hdf5
# Epoch 17/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.0850 - fbeta: 0.9738 - acc: 0.9763 - val_loss: 0.5935 - val_fbeta: 0.7868 - val_acc: 0.8020
#
# Epoch 00017: saving model to ../opt/ck-nn/Model.17-0.8020.hdf5
#
# Epoch 00017: saving model to ../opt/ck-nn/Model.17-0.8020.hdf5
# Epoch 18/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.1062 - fbeta: 0.9537 - acc: 0.9600 - val_loss: 0.5568 - val_fbeta: 0.8122 - val_acc: 0.8376
#
# Epoch 00018: saving model to ../opt/ck-nn/Model.18-0.8376.hdf5
#
# Epoch 00018: saving model to ../opt/ck-nn/Model.18-0.8376.hdf5
# Epoch 19/25
# 25/24 [==============================] - 0s 6ms/step - loss: 0.0912 - fbeta: 0.9712 - acc: 0.9787 - val_loss: 0.7091 - val_fbeta: 0.7056 - val_acc: 0.7259
#
# Epoch 00019: saving model to ../opt/ck-nn/Model.19-0.7259.hdf5
#
# Epoch 00019: saving model to ../opt/ck-nn/Model.19-0.7259.hdf5
# Epoch 20/25
# 25/24 [==============================] - 0s 6ms/step - loss: 0.0924 - fbeta: 0.9650 - acc: 0.9700 - val_loss: 0.5712 - val_fbeta: 0.7259 - val_acc: 0.7411
#
# Epoch 00020: saving model to ../opt/ck-nn/Model.20-0.7411.hdf5
#
# Epoch 00020: saving model to ../opt/ck-nn/Model.20-0.7411.hdf5
# Epoch 21/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.1029 - fbeta: 0.9626 - acc: 0.9663 - val_loss: 0.7943 - val_fbeta: 0.8122 - val_acc: 0.8223
#
# Epoch 00021: saving model to ../opt/ck-nn/Model.21-0.8223.hdf5
#
# Epoch 00021: saving model to ../opt/ck-nn/Model.21-0.8223.hdf5
# Epoch 22/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.0841 - fbeta: 0.9638 - acc: 0.9725 - val_loss: 0.6586 - val_fbeta: 0.7868 - val_acc: 0.8122
#
# Epoch 00022: saving model to ../opt/ck-nn/Model.22-0.8122.hdf5
#
# Epoch 00022: saving model to ../opt/ck-nn/Model.22-0.8122.hdf5
# Epoch 23/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.1139 - fbeta: 0.9563 - acc: 0.9625 - val_loss: 0.3427 - val_fbeta: 0.8629 - val_acc: 0.8832
#
# Epoch 00023: saving model to ../opt/ck-nn/Model.23-0.8832.hdf5
#
# Epoch 00023: saving model to ../opt/ck-nn/Model.23-0.8832.hdf5
# Epoch 24/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.1221 - fbeta: 0.9589 - acc: 0.9626 - val_loss: 0.6513 - val_fbeta: 0.7411 - val_acc: 0.7563
#
# Epoch 00024: saving model to ../opt/ck-nn/Model.24-0.7563.hdf5
#
# Epoch 00024: saving model to ../opt/ck-nn/Model.24-0.7563.hdf5
# Epoch 25/25
# 25/24 [==============================] - 0s 5ms/step - loss: 0.0863 - fbeta: 0.9713 - acc: 0.9750 - val_loss: 0.6655 - val_fbeta: 0.8173 - val_acc: 0.8477
#
# Epoch 00025: saving model to ../opt/ck-nn/Model.25-0.8477.hdf5
#
# Epoch 00025: saving model to ../opt/ck-nn/Model.25-0.8477.hdf5

# %%
n_classes = Y_data.shape[1]

# %%
labels=range(n_classes)

# %%
def eval_model(history, model):
    batch_size = 32
    score = model.evaluate(X_test, Y_test, steps=(int)(len(X_test) / batch_size))
    print('Evaluation loss: ', score[0])
    print('Evaluation accuracy: ', score[1])
    # summarize history for accuracy
    plt.plot(history.history['acc'], color='b', label='Training')
    plt.plot(history.history['val_acc'], color='g', label='Validation')
    plt.title('Accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(loc='upper left')
    plt.show()

    # summarize history for loss
    plt.plot(history.history['loss'], color='b', label='Training')
    plt.plot(history.history['val_loss'], color='g', label='Validation')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(loc='lower left')
    plt.show()
    y_pred = model.predict_classes(X_test)
    y_true = np.asarray([np.argmax(i) for i in Y_test])

    from sklearn.metrics import confusion_matrix
    import seaborn as sns

    cm = confusion_matrix(y_true, y_pred)
    cm_normalised = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    sns.set(font_scale=1.5) 
    fig, ax = plt.subplots(figsize=(10,10))
    ax = sns.heatmap(cm_normalised, annot=True, linewidths=0, square=False, 
                        cmap="Greens", yticklabels=labels, xticklabels=labels, vmin=0, vmax=np.max(cm_normalised), 
                        fmt=".2f", annot_kws={"size": 20})
    ax.set(xlabel='Predicted label', ylabel='True label')

# %%
eval_model(history, cnn_model)
# Out:
# 6/6 [==============================] - 0s 38ms/step
# Evaluation loss:  0.08863022923469543
# Evaluation accuracy:  0.9644669890403748

# %%
eval_model(nn_history, nn_model)
# Out:
# 6/6 [==============================] - 0s 15ms/step
# Evaluation loss:  0.7005571722984314
# Evaluation accuracy:  0.807106614112854
